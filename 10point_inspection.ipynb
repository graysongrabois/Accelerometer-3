# %% [markdown]
# # 10-Point Inspection — NHANES 2005 Accelerometry
# ### Biomedical Informatics · Accelerometer-Projecter
#
# | Point | Check | Command |
# |-------|-------|---------|
# | 1 | Shape | `df.shape` |
# | 2 | Columns | `df.columns` |
# | 3 | Data Types | `df.dtypes` |
# | 4 | First Look | `df.head()` |
# | 5 | Last Look | `df.tail()` |
# | 6 | Memory | `df.memory_usage()` |
# | 7 | Missing | `df.isnull().sum()` |
# | 8 | Duplicates | `df.duplicated()` |
# | 9 | Statistics | `df.describe()` |
# | 10 | Unique Values | `df.nunique()` |

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.3f}'.format)

MASTER_PATH = "/Users/graysongrabois/Documents/biomedical-informatics/Opioid Project/2005_master.csv"
AGG_PATH    = "/Users/graysongrabois/Documents/biomedical-informatics/Opioid Project/2005_patient_aggregated.csv"

print("Loading agg...")
agg = pd.read_csv(AGG_PATH)
print(f"  agg: {agg.shape}")

print("Loading master (large, ~30s)...")
master = pd.read_csv(MASTER_PATH)
print(f"  master: {master.shape}")
print("Done.")
# Out:
# Loading agg...
#   agg: (1528, 16)
# Loading master (large, ~30s)...
#   master: (15383678, 18)
# Done.

# %% [markdown]
# ---
# ## Point 1 — Shape
# How many rows and columns in each file?

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    rows, cols = df.shape
    print(f"{name}")
    print(f"  Rows         {rows:>15,}")
    print(f"  Columns      {cols:>15,}")
    print(f"  Total cells  {rows * cols:>15,}")
    print()
# Out:
# MASTER
#   Rows              15,383,678
#   Columns                   18
#   Total cells      276,906,204
#
# AGG
#   Rows                   1,528
#   Columns                   16
#   Total cells           24,448

# %% [markdown]
# ---
# ## Point 2 — Column Names
# What features do we have, and which are shared vs unique to each file?

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    print(f"{name} ({len(df.columns)} columns):")
    for i, col in enumerate(df.columns, 1):
        print(f"  {i:2}. {col}")
    print()

print("Only in AGG   :", sorted(set(agg.columns)    - set(master.columns)))
print("Only in MASTER:", sorted(set(master.columns) - set(agg.columns)))
# Out:
# MASTER (18 columns):
#    1. participant_id
#    2. day
#    3. hour
#    4. minute
#    5. intensity
#    6. steps
#    7. age
#    8. sex
#    9. race
#   10. poverty_ratio
#   11. hospitalized
#   12. num_hospitalizations
#   13. systolic_bp
#   14. diastolic_bp
#   15. weight_kg
#   16. height_cm
#   17. bmi
#   18. waist_cm
#
# AGG (16 columns):
#    1. participant_id
#    2. hospitalized
#    3. num_hospitalizations
#    4. age
#    5. sex
#    6. race
#    7. poverty_ratio
#    8. bmi
#    9. systolic_bp
#   10. diastolic_bp
#   11. weight_kg
#   12. height_cm
#   13. waist_cm
#   14. total_steps
#   15. avg_active_intensity
#   16. pct_zero
#
# Only in AGG   : ['avg_active_intensity', 'pct_zero', 'total_steps']
# Only in MASTER: ['day', 'hour', 'intensity', 'minute', 'steps']

# %% [markdown]
# ---
# ## Point 3 — Data Types
# How is each column stored?

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    print(f"=== {name} ===")
    print(df.dtypes.to_string())
    print(f"\n  Summary: {df.dtypes.value_counts().to_dict()}")
    print()
# Out:
# === MASTER ===
# participant_id            int64
# day                       int64
# hour                      int64
# minute                    int64
# intensity                 int64
# steps                     int64
# age                     float64
# sex                     float64
# race                    float64
# poverty_ratio           float64
# hospitalized              int64
# num_hospitalizations    float64
# systolic_bp             float64
# diastolic_bp            float64
# weight_kg               float64
# height_cm               float64
# bmi                     float64
# waist_cm                float64
#
#   Summary: {dtype('float64'): 11, dtype('int64'): 7}
#
# === AGG ===
# participant_id            int64
# hospitalized              int64
# num_hospitalizations      int64
# age                     float64
# sex                     float64
# race                    float64
# poverty_ratio           float64
# bmi                     float64
# systolic_bp             float64
# diastolic_bp            float64
# weight_kg               float64
# height_cm               float64
# waist_cm                float64
# total_steps               int64
# avg_active_intensity    float64
# pct_zero                float64
#
#   Summary: {dtype('float64'): 12, dtype('int64'): 4}

# %% [markdown]
# ---
# ## Point 4 — First Look

# %%
print("=== MASTER — first 5 rows ===")
display(master.head())
print("\n=== AGG — first 5 rows ===")
display(agg.head())
# Out:
# === MASTER — first 5 rows ===
#    participant_id  day  hour  minute  intensity  steps    age   sex  race  \
# 0           31132    5     0       0          0      0 70.000 1.000 3.000
# 1           31132    5     0       1          0      0 70.000 1.000 3.000
# 2           31132    5     0       2          0      0 70.000 1.000 3.000
# 3           31132    5     0       3          0      0 70.000 1.000 3.000
# 4           31132    5     0       4          0      0 70.000 1.000 3.000
#
#    poverty_ratio  hospitalized  num_hospitalizations  systolic_bp  \
# 0          5.000             0                   NaN      138.000
# 1          5.000             0                   NaN      138.000
# 2          5.000             0                   NaN      138.000
# 3          5.000             0                   NaN      138.000
# 4          5.000             0                   NaN      138.000
#
#    diastolic_bp  weight_kg  height_cm    bmi  waist_cm
# 0        60.000     69.500    167.600 24.740    96.500
# 1        60.000     69.500    167.600 24.740    96.500
# 2        60.000     69.500    167.600 24.740    96.500
# 3        60.000     69.500    167.600 24.740    96.500
# 4        60.000     69.500    167.600 24.740    96.500
# === AGG — first 5 rows ===
#    participant_id  hospitalized  num_hospitalizations    age   sex  race  \
# 0           31132             0                     0 70.000 1.000 3.000
# 1           31134             0                     0 73.000 1.000 3.000
# 2           31150             0                     0 79.000 1.000 3.000
# 3           31151             1                     1 59.000 2.000 4.000
# 4           31158             0                     0 71.000 1.000 3.000
#
#    poverty_ratio    bmi  systolic_bp  diastolic_bp  weight_kg  height_cm  \
# 0          5.000 24.740      138.000        60.000     69.500    167.600
# 1            NaN 30.630      130.000        68.000    101.900    182.400
# 2          1.220 28.930      144.000        74.000     85.000    171.400
# 3          3.030 29.510      136.000        76.000     82.900    167.600
# 4          3.710 21.650      154.000        74.000     69.200    178.800
#
#    waist_cm  total_steps  avg_active_intensity  pct_zero
# 0    96.500        85429               819.817    67.877
# 1   117.100        57684               581.463    67.292
# 2   107.700        59762               309.656    48.819
# 3   101.200        54210               313.785    55.476
# 4    85.500        65852               376.640    59.633

# %% [markdown]
# ---
# ## Point 5 — Last Look

# %%
print("=== MASTER — last 5 rows ===")
display(master.tail())
print("\n=== AGG — last 5 rows ===")
display(agg.tail())
# Out:
# === MASTER — last 5 rows ===
#           participant_id  day  hour  minute  intensity  steps    age   sex  \
# 15383673           41468    7    23      55          0      0 66.000 2.000
# 15383674           41468    7    23      56          0      0 66.000 2.000
# 15383675           41468    7    23      57          0      0 66.000 2.000
# 15383676           41468    7    23      58          0      0 66.000 2.000
# 15383677           41468    7    23      59          0      0 66.000 2.000
#
#           race  poverty_ratio  hospitalized  num_hospitalizations  \
# 15383673 1.000          1.780             0                   NaN
# 15383674 1.000          1.780             0                   NaN
# 15383675 1.000          1.780             0                   NaN
# 15383676 1.000          1.780             0                   NaN
# 15383677 1.000          1.780             0                   NaN
#
#           systolic_bp  diastolic_bp  weight_kg  height_cm    bmi  waist_cm
# 15383673      138.000        84.000     66.000    158.000 26.440    89.300
# 15383674      138.000        84.000     66.000    158.000 26.440    89.300
# 15383675      138.000        84.000     66.000    158.000 26.440    89.300
# 15383676      138.000        84.000     66.000    158.000 26.440    89.300
# 15383677      138.000        84.000     66.000    158.000 26.440    89.300
# === AGG — last 5 rows ===
#       participant_id  hospitalized  num_hospitalizations    age   sex  race  \
# 1523           41454             0                     0 66.000 1.000 3.000
# 1524           41460             0                     0 71.000 1.000 3.000
# 1525           41461             1                     1 85.000 1.000 3.000
# 1526           41466             0                     0 58.000 2.000 5.000
# 1527           41468             0                     0 66.000 2.000 1.000
#
#       poverty_ratio    bmi  systolic_bp  diastolic_bp  weight_kg  height_cm  \
# 1523          2.600 33.540      142.000        46.000    105.200    177.100
# 1524          5.000 28.660      108.000        74.000     84.500    171.700
# 1525          1.560 22.650      136.000        76.000     71.600    177.800
# 1526          1.340 33.650      160.000        84.000     79.900    154.100
# 1527          1.780 26.440      138.000        84.000     66.000    158.000
#
#       waist_cm  total_steps  avg_active_intensity  pct_zero
# 1523   123.300        33021               162.141    59.484
# 1524    96.100       127274               537.033    54.970
# 1525    97.500        22280               132.670    70.913
# 1526   114.200        34355               247.564    78.274
# 1527    89.300        39230               311.170    64.097

# %% [markdown]
# ---
# ## Point 6 — Memory Usage

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    mem = df.memory_usage(deep=True)
    print(f"=== {name} — {mem.sum() / 1e6:.1f} MB total ===")
    for col, val in (mem / 1e6).items():
        if col != 'Index':
            print(f"  {col:<25} {val:.2f} MB")
    print()
# Out:
# === MASTER — 2215.2 MB total ===
#   participant_id            123.07 MB
#   day                       123.07 MB
#   hour                      123.07 MB
#   minute                    123.07 MB
#   intensity                 123.07 MB
#   steps                     123.07 MB
#   age                       123.07 MB
#   sex                       123.07 MB
#   race                      123.07 MB
#   poverty_ratio             123.07 MB
#   hospitalized              123.07 MB
#   num_hospitalizations      123.07 MB
#   systolic_bp               123.07 MB
#   diastolic_bp              123.07 MB
#   weight_kg                 123.07 MB
#   height_cm                 123.07 MB
#   bmi                       123.07 MB
#   waist_cm                  123.07 MB
#
# === AGG — 0.2 MB total ===
#   participant_id            0.01 MB
#   hospitalized              0.01 MB
#   num_hospitalizations      0.01 MB
#   age                       0.01 MB
#   sex                       0.01 MB
#   race                      0.01 MB
#   poverty_ratio             0.01 MB
#   bmi                       0.01 MB
#   systolic_bp               0.01 MB
#   diastolic_bp              0.01 MB
#   weight_kg                 0.01 MB
#   height_cm                 0.01 MB
#   waist_cm                  0.01 MB
#   total_steps               0.01 MB
#   avg_active_intensity      0.01 MB
#   pct_zero                  0.01 MB

# %% [markdown]
# ---
# ## Point 7 — Missing Values

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    miss = df.isnull().sum()
    pct  = (miss / len(df) * 100).round(2)
    report = pd.DataFrame({'missing': miss, 'pct': pct})
    report = report[report['missing'] > 0].sort_values('pct', ascending=False)
    print(f"=== {name} ({len(df):,} rows) ===")
    if report.empty:
        print("  No missing values.")
    else:
        print(report.to_string())
    print()
# Out:
# === MASTER (15,383,678 rows) ===
#                        missing    pct
# num_hospitalizations  12960677 84.250
# poverty_ratio           917280  5.960
# waist_cm                519336  3.380
# bmi                     120960  0.790
# height_cm                80640  0.520
# weight_kg                70560  0.460
#
# === AGG (1,528 rows) ===
#                missing   pct
# poverty_ratio       91 5.960
# waist_cm            52 3.400
# bmi                 12 0.790
# height_cm            8 0.520
# weight_kg            7 0.460

# %% [markdown]
# ---
# ## Point 8 — Duplicates

# %%
# Full-row duplicates
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    n = df.duplicated().sum()
    print(f"{name} full-row duplicates: {n:,} ({n/len(df)*100:.2f}%)")

print()

# Composite key check for MASTER
n = master.duplicated(subset=['participant_id','day','hour','minute']).sum()
print(f"MASTER duplicate (id, day, hour, minute): {n:,}")

# Primary key check for AGG
n = agg.duplicated(subset='participant_id').sum()
print(f"AGG duplicate participant_id: {n:,}")
# Out:
# MASTER full-row duplicates: 0 (0.00%)
# AGG full-row duplicates: 0 (0.00%)
#
# MASTER duplicate (id, day, hour, minute): 0
# AGG duplicate participant_id: 0

# %% [markdown]
# ---
# ## Point 9 — Descriptive Statistics

# %%
print("=== AGG — describe (transposed) ===")
display(agg.describe().T)

print("\n=== MASTER — activity columns ===")
display(master[['intensity','steps']].describe().T)

print("\n=== MASTER — demographics (one row per patient) ===")
demo = ['age','sex','race','poverty_ratio','bmi','systolic_bp','diastolic_bp',
        'weight_kg','height_cm','waist_cm']
display(master.drop_duplicates('participant_id')[demo].describe().T)
# Out:
# === AGG — describe (transposed) ===
#                         count      mean       std       min       25%  \
# participant_id       1528.000 36431.130  2986.258 31132.000 33926.500
# hospitalized         1528.000     0.158     0.365     0.000     0.000
# num_hospitalizations 1528.000     0.240     0.689     0.000     0.000
# age                  1528.000    66.052    10.444    50.000    57.000
# sex                  1528.000     1.487     0.500     1.000     1.000
# race                 1528.000     2.947     0.944     1.000     3.000
# poverty_ratio        1437.000     2.740     1.570     0.000     1.330
# bmi                  1516.000    28.921     6.265    13.360    24.567
# systolic_bp          1528.000   134.220    22.434    74.000   118.000
# diastolic_bp         1528.000    71.056    12.978    20.000    62.000
# weight_kg            1521.000    80.960    19.764    35.900    66.800
# height_cm            1520.000   167.022    10.006   138.600   159.700
# waist_cm             1476.000   100.920    15.044    62.000    90.700
# total_steps          1528.000 49180.082 27798.760     7.000 28380.500
# avg_active_intensity 1528.000   331.723   153.958    58.220   217.069
# pct_zero             1528.000    63.765    11.689    25.139    55.704
#
#                            50%       75%        max
# participant_id       36523.500 38997.000  41468.000
# hospitalized             0.000     0.000      1.000
# num_hospitalizations     0.000     0.000      6.000
# age                     65.000    74.000     85.000
# sex                      1.000     2.000      2.000
# race                     3.000     3.000      5.000
# poverty_ratio            2.410     4.290      5.000
# bmi                     28.050    32.010     57.410
# systolic_bp            132.000   146.000    270.000
# diastolic_bp            72.000    78.000    124.000
# weight_kg               78.500    91.900    173.500
# height_cm              167.100   174.300    197.100
# waist_cm               100.000   110.200    155.700
# total_steps          46314.500 65866.500 175380.000
# avg_active_intensity   308.261   418.369   1207.863
# pct_zero                62.971    70.399     99.980
# === MASTER — activity columns ===
#                  count    mean     std   min   25%   50%    75%       max
# intensity 15383678.000 125.895 388.955 0.000 0.000 0.000 41.000 32767.000
# steps     15383678.000   4.885  13.150 0.000 0.000 0.000  2.000   184.000
# === MASTER — demographics (one row per patient) ===
#                  count    mean    std     min     25%     50%     75%     max
# age           1528.000  66.052 10.444  50.000  57.000  65.000  74.000  85.000
# sex           1528.000   1.487  0.500   1.000   1.000   1.000   2.000   2.000
# race          1528.000   2.947  0.944   1.000   3.000   3.000   3.000   5.000
# poverty_ratio 1437.000   2.740  1.570   0.000   1.330   2.410   4.290   5.000
# bmi           1516.000  28.921  6.265  13.360  24.567  28.050  32.010  57.410
# systolic_bp   1528.000 134.220 22.434  74.000 118.000 132.000 146.000 270.000
# diastolic_bp  1528.000  71.056 12.978  20.000  62.000  72.000  78.000 124.000
# weight_kg     1521.000  80.960 19.764  35.900  66.800  78.500  91.900 173.500
# height_cm     1520.000 167.022 10.006 138.600 159.700 167.100 174.300 197.100
# waist_cm      1476.000 100.920 15.044  62.000  90.700 100.000 110.200 155.700

# %% [markdown]
# ---
# ## Point 10 — Unique Values

# %%
for df, name in [(master, 'MASTER'), (agg, 'AGG')]:
    u = df.nunique().sort_values()
    print(f"=== {name} unique values per column ===")
    print(u.to_string())
    print(f"\n  Binary (2)     : {u[u==2].index.tolist()}")
    print(f"  Low card (3-10): {u[(u>2)&(u<=10)].index.tolist()}")
    print(f"  High card (>10): {u[u>10].index.tolist()}")
    print()
# Out:
# === MASTER unique values per column ===
# sex                        2
# hospitalized               2
# race                       5
# num_hospitalizations       6
# day                        7
# hour                      24
# age                       36
# diastolic_bp              49
# minute                    60
# systolic_bp               70
# steps                    185
# poverty_ratio            303
# height_cm                419
# waist_cm                 534
# weight_kg                648
# bmi                     1058
# participant_id          1528
# intensity               7722
#
#   Binary (2)     : ['sex', 'hospitalized']
#   Low card (3-10): ['race', 'num_hospitalizations', 'day']
#   High card (>10): ['hour', 'age', 'diastolic_bp', 'minute', 'systolic_bp', 'steps', 'poverty_ratio', 'height_cm', 'waist_cm', 'weight_kg', 'bmi', 'participant_id', 'intensity']
#
# === AGG unique values per column ===
# hospitalized               2
# sex                        2
# race                       5
# num_hospitalizations       7
# age                       36
# diastolic_bp              49
# systolic_bp               70
# poverty_ratio            303
# height_cm                419
# waist_cm                 534
# weight_kg                648
# bmi                     1058
# pct_zero                1281
# total_steps             1516
# participant_id          1528
# avg_active_intensity    1528
#
#   Binary (2)     : ['hospitalized', 'sex']
#   Low card (3-10): ['race', 'num_hospitalizations']
#   High card (>10): ['age', 'diastolic_bp', 'systolic_bp', 'poverty_ratio', 'height_cm', 'waist_cm', 'weight_kg', 'bmi', 'pct_zero', 'total_steps', 'participant_id', 'avg_active_intensity']

# %% [markdown]
# ---
# ## Final Checklist

# %%
print("=" * 52)
print("  FINAL DATA CHECKLIST")
print("=" * 52)

# ----------------------------------------------------------
# 1. File sizes
# ----------------------------------------------------------
print("\n[ ] File Sizes")
print(f"    master   {len(master):>12,} rows  x  {master.shape[1]} cols")
print(f"    agg      {len(agg):>12,} rows  x  {agg.shape[1]} cols")

# ----------------------------------------------------------
# 2. Patient key alignment
# ----------------------------------------------------------
print("\n[ ] Patient Key Alignment")
m_ids = set(master['participant_id'].unique())
a_ids = set(agg['participant_id'].unique())
unmatched = m_ids.symmetric_difference(a_ids)
print(f"    Unique IDs — master: {len(m_ids):,}   agg: {len(a_ids):,}")
if unmatched:
    print(f"    UNMATCHED: {sorted(unmatched)}")
else:
    print("    No unmatched patients   -->   PASS")

# ----------------------------------------------------------
# 3. Remaining missing values
# ----------------------------------------------------------
print("\n[ ] Remaining Missing Values (agg)")
miss = agg.isnull().sum()
miss = miss[miss > 0]
if miss.empty:
    print("    None   -->   PASS")
else:
    for col, n in miss.items():
        print(f"    {col:<22}  {n:>4} missing  ({n/len(agg)*100:.1f}%)")

# ----------------------------------------------------------
# 4. Physiological outlier check
# ----------------------------------------------------------
print("\n[ ] Physiological Outlier Check (agg)")
BOUNDS = {
    'age'         : (18, 120),
    'bmi'         : (10,  80),
    'systolic_bp' : (50, 300),
    'diastolic_bp': (20, 200),
    'weight_kg'   : (20, 300),
    'height_cm'   : (100, 230),
    'waist_cm'    : (40, 200),
}
any_bad = False
for col, (lo, hi) in BOUNDS.items():
    if col not in agg.columns:
        continue
    sub  = agg[col].dropna()
    nbad = ((sub < lo) | (sub > hi)).sum()
    if nbad:
        print(f"    {col:<22}  {nbad} values outside [{lo}, {hi}]  "
              f"(min={sub.min():.1f}, max={sub.max():.1f})")
        any_bad = True
if not any_bad:
    print("    All columns within physiological bounds   -->   PASS")

# Accelerometry bounds (master)
print("\n[ ] Accelerometry Bounds (master)")
checks = [
    ('intensity < 0',       (master['intensity'] < 0).sum()),
    ('steps < 0',           (master['steps'] < 0).sum()),
    ('steps > 200/min',     (master['steps'] > 200).sum()),
    ('intensity == 32767',  (master['intensity'] == 32767).sum()),
]
accel_clean = True
for label, n in checks:
    flag = '  WARN' if n > 0 else ''
    print(f"    {label:<28}  {n:,}{flag}")
    if n > 0:
        accel_clean = False
if accel_clean:
    print("    All accelerometry checks clean   -->   PASS")

# ----------------------------------------------------------
# 5. Avg daily intensity: hospitalized vs not
# ----------------------------------------------------------
print("\n[ ] Avg Daily Intensity — Hospitalized vs Not")
daily = (master.groupby(['participant_id','day'])['intensity']
               .mean()
               .reset_index()
               .merge(agg[['participant_id','hospitalized']], on='participant_id'))
grp = daily.groupby('hospitalized')['intensity'].mean()
not_h = grp.get(0, float('nan'))
hosp  = grp.get(1, float('nan'))
print(f"    Not hospitalized  {not_h:>7.1f}  avg counts/day")
print(f"    Hospitalized      {hosp:>7.1f}  avg counts/day")
print(f"    Difference        {not_h - hosp:>7.1f}  ({'not-hosp more active' if not_h > hosp else 'hosp more active'})")

print("\n" + "=" * 52)
# Out:
# ====================================================
#   FINAL DATA CHECKLIST
# ====================================================
#
# [ ] File Sizes
#     master     15,383,678 rows  x  18 cols
#     agg             1,528 rows  x  16 cols
#
# [ ] Patient Key Alignment
#     Unique IDs — master: 1,528   agg: 1,528
#     No unmatched patients   -->   PASS
#
# [ ] Remaining Missing Values (agg)
#     poverty_ratio             91 missing  (6.0%)
#     bmi                       12 missing  (0.8%)
#     weight_kg                  7 missing  (0.5%)
#     height_cm                  8 missing  (0.5%)
#     waist_cm                  52 missing  (3.4%)
#
# [ ] Physiological Outlier Check (agg)
#     All columns within physiological bounds   -->   PASS
#
# [ ] Accelerometry Bounds (master)
#     intensity < 0                 0
#     steps < 0                     0
#     steps > 200/min               0
#     intensity == 32767            7  WARN
#
# [ ] Avg Daily Intensity — Hospitalized vs Not
#     Not hospitalized    132.3  avg counts/day
#     Hospitalized         91.5  avg counts/day
#     Difference           40.8  (not-hosp more active)
#
# ====================================================
